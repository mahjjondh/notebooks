# %%
#!/usr/bin/env python
# coding: utf-8

from selenium import webdriver
import os
import time
from selenium.webdriver.common.keys import Keys
import numpy as np
import pandas as pd
import time
from selenium.webdriver.support.select import Select
import re

# %% [markdown]
# # Scraping das coordenadas

# %%
chromedriver = "chromedriver.exe"
os.environ["webddriver.chromedriver"] = chromedriver
driver = webdriver.Chrome(chromedriver)

# %%
driver.get("https://www.google.com.br/maps/@-15.8429902,-48.1101308,15z")

# %%
df = pd.read_excel('parques_brasilia.xlsx','Planilha1')

# %%
len_parques = len(df['Nome'])
len_parques
# Out:
# 73

# %%
csv_parques_coord = open('parques_coord.csv','w+')
csv_parques_coord.writelines('nome|url|latitude|longitude|classificacao\n')

# %%
for item in range(1, len_parques):
    text_search = driver.find_element_by_tag_name('input')
    text_search.clear()
    text_search.click()
    text_search.send_keys(str(df['Nome'][item])+' Distrito Federal')
    text_search.send_keys(Keys.ENTER)
    time.sleep(5)
    url = driver.current_url
    parque_nome = df['Nome'][item]
    print(str(parque_nome)+'\n')
    print(str(url)+'\n')
    lat_long = re.search(r'@(.*?),\d\dz',url).group(1) #add after
    lat_long_split = lat_long.split(',')
    latitude = lat_long_split[0]
    longitude = lat_long_split[1]
    try:
        classificacao = driver.find_elements_by_class_name('section-rating-term')
        classifica = classificacao[1].text
    except:
        classificacao = 'parque'
    
    
    """
    try:
        lat_long = re.search(r'@(.*?),17z',url).group(1) #add after
        lat_long_split = lat_long.split(',')
        latitude = lat_long_split[0]
        longitude = lat_long_split[1]
    except:
        lat_long = re.search(r'@(.*?),14z',url).group(1) #add after
        lat_long_split = lat_long.split(',')
        latitude = lat_long_split[0]
        longitude = lat_long_split[1]
    """    
    csv_parques_coord.writelines(str(parque_nome)+'|'+str(url)+'|'+str(latitude)+'|'+str(longitude)+'|'+str(classifica)+'\n')
    print('latitude: '+str(latitude))
    print('longitude: '+str(longitude)+'\n')
    print('classificação: '+str(classifica)+'\n')
    time.sleep(9)
# Out:
# Parque Uso Múltiplo do Lago Norte
#
# https://www.google.com.br/maps/place/Parque+de+Uso+M%C3%BAltiplo+Morro+do+Careca/@-15.7337689,-47.8432502,17z/data=!3m1!4b1!4m5!3m4!1s0x935a3c0047707efb:0x6329a9eeb7d1b94a!8m2!3d-15.7337741!4d-47.8410615
#
# latitude: -15.7337689
# longitude: -47.8432502
#
# classificação: Parque
#
# Parque de Uso Múltiplo da Enseada Norte
#
# https://www.google.com.br/maps/search/Parque+de+Uso+M%C3%BAltiplo+da+Enseada+Norte+Distrito+Federal/@-15.8169678,-47.899443,14z/data=!3m1!4b1
#
# latitude: -15.8169678
# longitude: -47.899443
#
# classificação: Parque
#
# Parque Recreativo e Ecológico Canela de Ema
#
# https://www.google.com.br/maps/search/Parque+Recreativo+e+Ecol%C3%B3gico+Canela+de+Ema+Distrito+Federal/@-15.6428341,-47.8317532,15z/data=!3m1!4b1
#
# latitude: -15.6428341
# longitude: -47.8317532
#
# classificação: Parque
#
# Parque Vivencial Denner
#
# https://www.google.com.br/maps/search/Parque+Vivencial+Denner+Distrito+Federal/@-15.6345038,-47.7737273,17z/data=!3m1!4b1
#
# latitude: -15.6345038
# longitude: -47.7737273
#
# classificação: Parque
#
# Parque das Aves
#
# https://www.google.com.br/maps/place/Parque+de+Uso+M%C3%BAltiplo+da+Vila+Planalto/@-15.7981007,-47.8512315,17z/data=!3m1!4b1!4m5!3m4!1s0x935a3b5a49a69625:0xf53fcf6a27a8d805!8m2!3d-15.7981059!4d-47.8490428
#
# latitude: -15.7981007
# longitude: -47.8512315
#
# classificação: Parque
#
# Parque Ecológico Ezechias Heringer
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+do+Guar%C3%A1+Ezechias+Heringer/@-15.8349731,-47.9711852,17z/data=!3m1!4b1!4m5!3m4!1s0x935a31d7057a8591:0x4ed2ea551c7c85eb!8m2!3d-15.8349783!4d-47.9689965
#
# latitude: -15.8349731
# longitude: -47.9711852
#
# classificação: Parque
#
# Parque Bosque dos Tribunais
#
# https://www.google.com.br/maps/place/Bosque+dos+Tribunais/@-15.8088175,-47.8652322,17z/data=!3m1!4b1!4m5!3m4!1s0x935a3b35f1c971af:0xe94d751433a3c3f4!8m2!3d-15.8088227!4d-47.8630435
#
# latitude: -15.8088175
# longitude: -47.8652322
#
# classificação: Parque
#
# Parque Bosque dos Constituintes
#
# https://www.google.com.br/maps/place/St.+de+Administra%C3%A7%C3%A3o+Federal+Sul+Bosque+dos+Constituintes+-+Bras%C3%ADlia,+DF,+70297-400/@-15.8037722,-47.86081,16z/data=!3m1!4b1!4m5!3m4!1s0x935a3b4f308d3929:0x50acf9c6f9f094e2!8m2!3d-15.8035031!4d-47.8572295
#
# latitude: -15.8037722
# longitude: -47.86081
#
# classificação: Parque
#
# Parque de Uso Múltiplo da Asa Sul
#
# https://www.google.com.br/maps/place/Parque+de+Uso+M%C3%BAltiplo+Asa+Sul/@-15.8359085,-47.9170126,17z/data=!3m1!4b1!4m5!3m4!1s0x935a255a5b8f859f:0xcbff34a474603c64!8m2!3d-15.8359137!4d-47.9148239
#
# latitude: -15.8359085
# longitude: -47.9170126
#
# classificação: Parque
#
# Parque Ecológico Olhos d’Água
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+Olhos+d%E2%80%99%C3%81gua+Distrito+Federal/@-15.8576531,-48.0560944,12z/data=!3m1!4b1
#
# latitude: -15.8576531
# longitude: -48.0560944
#
# classificação: Parque
#
# Parque Urbano e Vivencial Vila Planalto
#
# https://www.google.com.br/maps/search/Parque+Urbano+e+Vivencial+Vila+Planalto+Distrito+Federal/@-15.8984032,-47.9953644,12z/data=!3m1!4b1
#
# latitude: -15.8984032
# longitude: -47.9953644
#
# classificação: Parque
#
# Parque Ecológico Ponte Alta do Gama
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+Ponte+Alta+do+Gama+Distrito+Federal/@-15.8980505,-47.9953646,12z/data=!3m1!4b1
#
# latitude: -15.8980505
# longitude: -47.9953646
#
# classificação: Parque
#
# Parque Recreativo do Gama (Prainha)
#
# https://www.google.com.br/maps/place/Parque+Distrital+do+Gama+-+Prainha/@-16.0408596,-48.0562404,17z/data=!3m1!4b1!4m5!3m4!1s0x9359804e99e4791b:0x7e51ff89c22990d5!8m2!3d-16.0408648!4d-48.0540517
#
# latitude: -16.0408596
# longitude: -48.0562404
#
# classificação: Permanentemente fechado
#
# Parque Urbano e Vivencial do Gama
#
# https://www.google.com.br/maps/place/Parque+Urbano+e+Vivencial+do+Gama/@-16.0049448,-48.0704688,16z/data=!3m1!4b1!4m5!3m4!1s0x935a2aa40d6256ed:0xc996028cb4556eb5!8m2!3d-16.0054499!4d-48.0661649
#
# latitude: -16.0049448
# longitude: -48.0704688
#
# classificação: Belezas naturais
#
# Parque do Cortado
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+do+Cortado/@-15.8164222,-48.0784664,17z/data=!3m1!4b1!4m5!3m4!1s0x935a332de53d177d:0x6baaebc553106f77!8m2!3d-15.8164274!4d-48.0762777
#
# latitude: -15.8164222
# longitude: -48.0784664
#
# classificação: Parque
#
# Parque Ecológico Saburo Onoyama
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+Saburo+Onoyama/@-15.8453374,-48.0551829,17z/data=!3m1!4b1!4m5!3m4!1s0x935a3291a7c2a011:0x799c5a7d307e0611!8m2!3d-15.8453426!4d-48.0529942
#
# latitude: -15.8453374
# longitude: -48.0551829
#
# classificação: Parque ecológico
#
# Parque Ecológico Veredinha
#
# https://www.google.com.br/maps/place/Parque+Veredinha/@-15.6715271,-48.2002777,17z/data=!3m1!4b1!4m5!3m4!1s0x935bb6d66c49be0b:0x269b87869037bd51!8m2!3d-15.6715323!4d-48.198089
#
# latitude: -15.6715271
# longitude: -48.2002777
#
# classificação: Parque
#
# Parque Ecológico dos Jequitibás
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+dos+Jequitib%C3%A1s/@-15.641109,-47.790932,17z/data=!3m1!4b1!4m5!3m4!1s0x935a4076af3279cf:0xa8a2f065e293e7e9!8m2!3d-15.6411142!4d-47.7887433
#
# latitude: -15.641109
# longitude: -47.790932
#
# classificação: Parque ecológico
#
# Parque Ecológico e Vivencial de Sobradinho
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+e+Vivencial+de+Sobradinho+Distrito+Federal/@-15.7141723,-47.9013736,12z/data=!3m1!4b1
#
# latitude: -15.7141723
# longitude: -47.9013736
#
# classificação: Parque ecológico
#
# Parque Ambiental Colégio Agrícola de Brasília
#
# https://www.google.com.br/maps/search/Parque+Ambiental+Col%C3%A9gio+Agr%C3%ADcola+de+Bras%C3%ADlia+Distrito+Federal/@-15.7131562,-48.1115261,10z/data=!3m1!4b1
#
# latitude: -15.7131562
# longitude: -48.1115261
#
# classificação: Parque ecológico
#
# Parque de Uso Múltiplo Vale do Amanhecer
#
# https://www.google.com.br/maps/place/Parque+de+Uso+M%C3%BAltiplo+da+Vila+Planalto/@-15.7981007,-47.8512315,17z/data=!3m1!4b1!4m5!3m4!1s0x935a3b5a49a69625:0xf53fcf6a27a8d805!8m2!3d-15.7981059!4d-47.8490428
#
# latitude: -15.7981007
# longitude: -47.8512315
#
# classificação: Parque
#
# Parque Ecológico do DER
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+do+DER+Distrito+Federal/@-15.7980102,-47.8840624,13z/data=!3m1!4b1
#
# latitude: -15.7980102
# longitude: -47.8840624
#
# classificação: Parque
#
# Parque Ecológico dos Pequizeiros
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+dos+Pequizeiros/@-15.680035,-47.6212783,17z/data=!3m1!4b1!4m5!3m4!1s0x935a11f627e3fd6b:0x954dc6be91d07476!8m2!3d-15.6800402!4d-47.6190896
#
# latitude: -15.680035
# longitude: -47.6212783
#
# classificação: Reserva natural
#
# Parque Ecológico e Vivencial Cachoeira do Pipiripau
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+de+Riacho+Fundo/@-15.8870797,-48.0256496,17z/data=!3m1!4b1!4m5!3m4!1s0x935a2db4e05dd9fd:0x1fd4da0f38b4b21d!8m2!3d-15.8870849!4d-48.0234609
#
# latitude: -15.8870797
# longitude: -48.0256496
#
# classificação: Parque ecológico
#
# Parque Ecológico e Vivencial da Lagoa Joaquim de Medeiros
#
# https://www.google.com.br/maps/place/Lagoa+Joaquim+Medeiros/@-15.6342531,-47.6920194,17z/data=!3m1!4b1!4m5!3m4!1s0x935a14a427ffdded:0x3945cf1a2e5ba91d!8m2!3d-15.6341102!4d-47.6892101
#
# latitude: -15.6342531
# longitude: -47.6920194
#
# classificação: Lago
#
# Parque Ecológico e Vivencial do Retirinho
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+e+Vivencial+do+Retirinho/@-15.6055302,-47.6420268,15z/data=!3m1!4b1!4m5!3m4!1s0x935a6d321098de17:0x6df5a15922e5e583!8m2!3d-15.6062842!4d-47.6332155
#
# latitude: -15.6055302
# longitude: -47.6420268
#
# classificação: Belezas naturais
#
# Parque Ecológico Vivencial Estância
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+Vivencial+Est%C3%A2ncia+Distrito+Federal/@-15.6051343,-47.7733579,11z/data=!3m1!4b1
#
# latitude: -15.6051343
# longitude: -47.7733579
#
# classificação: Belezas naturais
#
# Parque Recreativo Sucupira
#
# https://www.google.com.br/maps/search/Parque+Recreativo+Sucupira+Distrito+Federal/@-15.6043841,-47.7733585,11z/data=!3m1!4b1
#
# latitude: -15.6043841
# longitude: -47.7733585
#
# classificação: Belezas naturais
#
# Parque de Uso Múltiplo das Esculturas
#
# https://www.google.com.br/maps/place/Parque+de+Uso+M%C3%BAltiplo+das+Esculturas/@-15.815665,-47.7812679,17z/data=!3m1!4b1!4m5!3m4!1s0x935a2310cd20e4c9:0xb63d734074aec932!8m2!3d-15.8156702!4d-47.7790792
#
# latitude: -15.815665
# longitude: -47.7812679
#
# classificação: Parque ecológico
# Parque Urbano do Paranoá e ARIE Paranoá Sul
#
# https://www.google.com.br/maps/search/Parque+Urbano+do+Parano%C3%A1+e+ARIE+Parano%C3%A1+Sul+Distrito+Federal/@-15.8156179,-47.7965888,14z/data=!3m1!4b1
#
# latitude: -15.8156179
# longitude: -47.7965888
#
# classificação: Parque ecológico
#
# Parque Ecológico Córrego da Onça
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+C%C3%B3rrego+da+On%C3%A7a+Distrito+Federal/@-15.8153995,-47.8491196,12z/data=!3m1!4b1
#
# latitude: -15.8153995
# longitude: -47.8491196
#
# classificação: Parque ecológico
#
# Parque Ecológico Lauro Muller (Ecológico do Catetinho)
#
# https://www.google.com.br/maps/place/Parque+de+Uso+M%C3%BAltiplo+da+Vila+Planalto/@-15.7981007,-47.8512315,17z/data=!3m1!4b1!4m5!3m4!1s0x935a3b5a49a69625:0xf53fcf6a27a8d805!8m2!3d-15.7981059!4d-47.8490428
#
# latitude: -15.7981007
# longitude: -47.8512315
#
# classificação: Parque
#
# Parque Ecológico Luiz Cruls
#
# https://www.google.com.br/maps/place/Parque+de+Uso+M%C3%BAltiplo+da+Vila+Planalto/@-15.7981007,-47.8512315,17z/data=!3m1!4b1!4m5!3m4!1s0x935a3b5a49a69625:0xf53fcf6a27a8d805!8m2!3d-15.7981059!4d-47.8490428
#
# latitude: -15.7981007
# longitude: -47.8512315
#
# classificação: Parque
#
# Parque Recreativo do Núcleo Bandeirante
#
# https://www.google.com.br/maps/search/Parque+Recreativo+do+N%C3%BAcleo+Bandeirante+Distrito+Federal/@-15.8741652,-47.9732686,15z/data=!3m1!4b1
#
# latitude: -15.8741652
# longitude: -47.9732686
#
# classificação: Parque
#
# Parque Ecológico do Descoberto
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+do+Descoberto+Distrito+Federal/@-15.874059,-47.9995334,13z/data=!3m1!4b1
#
# latitude: -15.874059
# longitude: -47.9995334
#
# classificação: Parque
#
# Parque Recreativo do Setor “O”
#
# https://www.google.com.br/maps/search/Parque+Recreativo+do+Setor+%E2%80%9CO%E2%80%9D+Distrito+Federal/@-15.7888441,-48.1274983,17z/data=!3m1!4b1
#
# latitude: -15.7888441
# longitude: -48.1274983
#
# classificação: Parque
#
# Parque Ecológico e Vivencial dos Eucaliptos
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+e+Vivencial+dos+Eucaliptos+Distrito+Federal/@-15.7480952,-47.8663528,13z/data=!3m1!4b1
#
# latitude: -15.7480952
# longitude: -47.8663528
#
# classificação: Parque
#
# Parque Ecológico Vivencial Gatumé
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+Vivencial+Gatum%C3%A9+Distrito+Federal/@-15.7479244,-47.8663528,13z/data=!3m1!4b1
#
# latitude: -15.7479244
# longitude: -47.8663528
#
# classificação: Parque
#
# Parque Três Meninas
#
# https://www.google.com.br/maps/place/Parque+Tr%C3%AAs+Meninas/@-15.8741389,-48.1099007,17z/data=!3m1!4b1!4m5!3m4!1s0x935bd29c8f43cd49:0x87136844db6d1a74!8m2!3d-15.8741441!4d-48.107712
#
# latitude: -15.8741389
# longitude: -48.1099007
#
# classificação: Parque estadual
#
# Parque Ecológico do Tororó
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+do+Toror%C3%B3+Distrito+Federal/@-15.9681154,-47.8519046,14z/data=!3m1!4b1
#
# latitude: -15.9681154
# longitude: -47.8519046
#
# classificação: Parque estadual
#
# Parque Recreativo de Santa Maria
#
# https://www.google.com.br/maps/search/Parque+Recreativo+de+Santa+Maria+Distrito+Federal/@-15.9680314,-47.8519046,14z/data=!3m1!4b1
#
# latitude: -15.9680314
# longitude: -47.8519046
#
# classificação: Parque estadual
#
# Parque Ecológico de São Sebastião
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+de+S%C3%A3o+Sebasti%C3%A3o+Distrito+Federal/@-15.9679475,-47.8519046,14z/data=!3m1!4b1
#
# latitude: -15.9679475
# longitude: -47.8519046
#
# classificação: Parque estadual
#
# Parque Ecológico e Vivencial do Recanto das Emas
#
# https://www.google.com.br/maps/place/Cachoeira+Monjolo/@-15.9270664,-48.0879964,17z/data=!3m1!4b1!4m5!3m4!1s0x935bd34eaf732f99:0x99b9e45352726b00!8m2!3d-15.9270716!4d-48.0858077
#
# latitude: -15.9270664
# longitude: -48.0879964
#
# classificação: Parque ecológico
#
# Parque Ecológico das Copaíbas
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+das+Copa%C3%ADbas/@-15.8256753,-47.8093642,17z/data=!3m1!4b1!4m5!3m4!1s0x935a233d9615e7db:0x7d26063c55599a3a!8m2!3d-15.8256805!4d-47.8071755
#
# latitude: -15.8256753
# longitude: -47.8093642
#
# classificação: Parque ecológico
#
# Parque Ecológico Bernardo Sayão(Ecológico do Rasgado)
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico%C2%A0Bernardo+Say%C3%A3o(Ecol%C3%B3gico+do+Rasgado)+Distrito+Federal/@-15.689259,-48.1433034,10z/data=!3m1!4b1
#
# latitude: -15.689259
# longitude: -48.1433034
#
# classificação: Parque ecológico
#
# Parque Ecológico Dom Bosco
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+Dom+Bosco/@-15.7980915,-47.8076934,17z/data=!3m1!4b1!4m5!3m4!1s0x935a22d5742165f7:0xed71e2dc767fbbbc!8m2!3d-15.7980967!4d-47.8055047
#
# latitude: -15.7980915
# longitude: -47.8076934
#
# classificação: Parque ecológico
#
# Parque Vivencial e Ecológico Canjerana
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+Vivencial+Do+Parano%C3%A1/@-15.7875781,-47.7825136,17z/data=!3m1!4b1!4m5!3m4!1s0x935a3d496e73268f:0x84b4f037a70be903!8m2!3d-15.7875833!4d-47.7803249
#
# latitude: -15.7875781
# longitude: -47.7825136
#
# classificação: Parque
#
# Parque Ecológico Península Sul
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+Pen%C3%ADnsula+Sul/@-15.828179,-47.8576635,17z/data=!3m1!4b1!4m5!3m4!1s0x935a24bda4ac7235:0xdf9f2cea847bf12b!8m2!3d-15.8281842!4d-47.8554748
#
# latitude: -15.828179
# longitude: -47.8576635
#
# classificação: Parque
#
# Parque Vivencial do Anfiteatro Natural do Lago Sul
#
# https://www.google.com.br/maps/place/Parque+Asa+Delta/@-15.8370335,-47.8679047,17z/data=!3m1!4b1!4m5!3m4!1s0x935a24ec771c06ad:0x331370d2ee41702f!8m2!3d-15.8370387!4d-47.865716
#
# latitude: -15.8370335
# longitude: -47.8679047
#
# classificação: Parque ecológico
#
# Parque Ecológico Sementes do Itapoã
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+Vivencial+Do+Parano%C3%A1/@-15.7875781,-47.7825136,17z/data=!3m1!4b1!4m5!3m4!1s0x935a3d496e73268f:0x84b4f037a70be903!8m2!3d-15.7875833!4d-47.7803249
#
# latitude: -15.7875781
# longitude: -47.7825136
#
# classificação: Parque
#
# Parque ecológico e Vivencial do Riacho Fundo
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+de+Riacho+Fundo/@-15.8870797,-48.0256496,17z/data=!3m1!4b1!4m5!3m4!1s0x935a2db4e05dd9fd:0x1fd4da0f38b4b21d!8m2!3d-15.8870849!4d-48.0234609
#
# latitude: -15.8870797
# longitude: -48.0256496
#
# classificação: Parque ecológico
#
# Parque Vivencial do Morro do Careca
#
# https://www.google.com.br/maps/search/Parque+Vivencial+do+Morro+do+Careca+Distrito+Federal/@-15.8029616,-47.9867473,11z/data=!3m1!4b1
#
# latitude: -15.8029616
# longitude: -47.9867473
#
# classificação: Parque ecológico
#
# Parque Ecológico das Garças
#
# https://www.google.com.br/maps/place/Parque+das+Gar%C3%A7as/@-15.7714712,-47.8351586,17z/data=!3m1!4b1!4m5!3m4!1s0x935a3c88bf32c1a3:0xb8e1862fbc09dc85!8m2!3d-15.7714764!4d-47.8329699
#
# latitude: -15.7714712
# longitude: -47.8351586
#
# classificação: Parque
#
# Parque Ecológico Taquari
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+Taquari+Distrito+Federal/@-15.7713807,-47.8679895,13z/data=!3m1!4b1
#
# latitude: -15.7713807
# longitude: -47.8679895
#
# classificação: Parque
#
# Parque Ecológico da Vila Varjão
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+E+Vivencial+Da+Vila+Varj%C3%A3o/@-15.7087727,-47.8845302,17z/data=!3m1!4b1!4m5!3m4!1s0x935a39077b2839eb:0xceb00dbab989bc5c!8m2!3d-15.7087779!4d-47.8823415
#
# latitude: -15.7087727
# longitude: -47.8845302
#
# classificação: Parque ecológico
#
# Parque Urbano da Vila Estrutural
#
# https://www.google.com.br/maps/search/Parque+Urbano+da+Vila+Estrutural+Distrito+Federal/@-15.7085911,-47.9523819,12z/data=!3m1!4b1
#
# latitude: -15.7085911
# longitude: -47.9523819
#
# classificação: Parque ecológico
#
# Parque Ecológico e Vivencial da Candangolândia (Pinheiros)
#
# https://www.google.com.br/maps/place/Parque+Vivencial+Parano%C3%A1/@-15.7896784,-47.7832066,17z/data=!3m1!4b1!4m5!3m4!1s0x935a3d4bcacb3f61:0x580f6f3b54ac6979!8m2!3d-15.7896836!4d-47.7810179
#
# latitude: -15.7896784
# longitude: -47.7832066
#
# classificação: Parque
#
# Parque de Areal
#
# https://www.google.com.br/maps/search/Parque+de+Areal+Distrito+Federal/@-15.8064303,-48.0983904,12z/data=!3m1!4b1
#
# latitude: -15.8064303
# longitude: -48.0983904
#
# classificação: Parque
#
# Parque Ecológico de Águas Claras
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+de+%C3%81guas+Claras+-+%C3%81guas+Claras,+Bras%C3%ADlia+-+DF,+70297-400/@-15.8328693,-48.0303371,16z/data=!3m1!4b1!4m5!3m4!1s0x935a326bf6238365:0x9f7cf21c9722d014!8m2!3d-15.8333849!4d-48.0245655
#
# latitude: -15.8328693
# longitude: -48.0303371
#
# classificação: Parque
# Parque de Uso Múltiplo das Sucupiras
#
# https://www.google.com.br/maps/place/Parque+Ecol%C3%B3gico+das+Sucupiras/@-15.7836669,-47.9272274,17z/data=!3m1!4b1!4m5!3m4!1s0x935a3083ba492139:0x7db689fe40f456a4!8m2!3d-15.7836721!4d-47.9250387
#
# latitude: -15.7836669
# longitude: -47.9272274
#
# classificação: Parque
#
# Parque Urbano do Sudoeste
#
# https://www.google.com.br/maps/place/Parque+Bosque+do+Sudoeste/@-15.7961128,-47.9274101,17z/data=!3m1!4b1!4m5!3m4!1s0x935a30793fe99165:0xfeebbd143d8f74fc!8m2!3d-15.796118!4d-47.9252214
#
# latitude: -15.7961128
# longitude: -47.9274101
#
# classificação: Parque
#
# Parque de Uso Múltiplo Centro de Lazer e Cultural Viva Sobradinho (Sobradinho II)
#
# https://www.google.com.br/maps/search/Parque+de+Uso+M%C3%BAltiplo+Centro+de+Lazer+e+Cultural+Viva+Sobradinho+(Sobradinho+II)+Distrito+Federal/@-15.7120917,-47.8985664,12z/data=!3m1!4b1
#
# latitude: -15.7120917
# longitude: -47.8985664
#
# classificação: Parque
#
# Parque Burle Marx
#
# https://www.google.com.br/maps/place/Parque+Burle+Marx+-+Bras%C3%ADlia,+DF,+70297-400/@-15.7371973,-47.9099681,17z/data=!3m1!4b1!4m5!3m4!1s0x935a39ee01b7483f:0xbffee7d689be441d!8m2!3d-15.7372025!4d-47.9077794
#
# latitude: -15.7371973
# longitude: -47.9099681
#
# classificação: Parque
#
# Parque Recreativo de Taguatinga
#
# https://www.google.com.br/maps/search/Parque+Recreativo+de+Taguatinga+Distrito+Federal/@-15.7370157,-47.9778198,12z/data=!3m1!4b1
#
# latitude: -15.7370157
# longitude: -47.9778198
#
# classificação: Parque
#
# Parque Ecológico Irmão Afonso Hauss
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+Irm%C3%A3o+Afonso+Hauss+Distrito+Federal/@-15.7366629,-47.9778199,12z/data=!3m1!4b1
#
# latitude: -15.7366629
# longitude: -47.9778199
#
# classificação: Parque
#
# Parque das Corujas
#
# https://www.google.com.br/maps/place/Ch%C3%A1cara+Toca+da+Coruja/@-15.779587,-48.0047571,17z/data=!3m1!4b1!4m5!3m4!1s0x935a33fc32072afd:0xffd81d2c55b72fd0!8m2!3d-15.7795922!4d-48.0025684
#
# latitude: -15.779587
# longitude: -48.0047571
#
# classificação: Parque
#
# Parque Lagoinha
#
# https://www.google.com.br/maps/search/Parque+Lagoinha+Distrito+Federal/@-15.8049003,-47.8397245,10z/data=!3m1!4b1
#
# latitude: -15.8049003
# longitude: -47.8397245
#
# classificação: Parque
#
# Parque Ecológico Garça Branca
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+Gar%C3%A7a+Branca+Distrito+Federal/@-15.8032197,-47.8397266,10z/data=!3m1!4b1
#
# latitude: -15.8032197
# longitude: -47.8397266
#
# classificação: Parque
#
# Parque Distrital Salto do Tororó
#
# https://www.google.com.br/maps/search/Parque+Distrital+Salto+do+Toror%C3%B3+Distrito+Federal/@-15.9625443,-47.8532731,14z/data=!3m1!4b1
#
# latitude: -15.9625443
# longitude: -47.8532731
#
# classificação: Parque
#
# Parque Distrital Boca da Mata
#
# https://www.google.com.br/maps/search/Parque+Distrital+Boca+da+Mata+Distrito+Federal/@-15.8669078,-48.0556884,15z/data=!3m1!4b1
#
# latitude: -15.8669078
# longitude: -48.0556884
#
# classificação: Parque
#
# Parque Ecológico Cachoeirinha
#
# https://www.google.com.br/maps/search/Parque+Ecol%C3%B3gico+Cachoeirinha+Distrito+Federal/@-15.8668016,-48.0819532,13z/data=!3m1!4b1
#
# latitude: -15.8668016
# longitude: -48.0819532
#
# classificação: Parque
#
# Parque de Uso Múltiplo Metropolitano
#
# https://www.google.com.br/maps/search/Parque+de+Uso+M%C3%BAltiplo+Metropolitano+Distrito+Federal/@-15.8169678,-47.899443,14z/data=!3m1!4b1
#
# latitude: -15.8169678
# longitude: -47.899443
#
# classificação: Parque

# %%
csv_parques_coord.flush()
csv_parques_coord.close()

# %% [markdown]
# # Criação do mapa a partir do csv criado com o scraping

# %%
df_parques = pd.read_csv('parques_coord.csv',delimiter='|', encoding='iso-8859-1')
df_parques = df_parques.iloc[0:]
df_parques
# Out:
#                                            nome  \
# 0             Parque Uso Múltiplo do Lago Norte
# 1       Parque de Uso Múltiplo da Enseada Norte
# 2   Parque Recreativo e Ecológico Canela de Ema
# 3                       Parque Vivencial Denner
# 4                               Parque das Aves
# ..                                          ...
# 67                Parque Ecológico Garça Branca
# 68             Parque Distrital Salto do Tororó
# 69                Parque Distrital Boca da Mata
# 70                Parque Ecológico Cachoeirinha
# 71         Parque de Uso Múltiplo Metropolitano
#
#                                                   url   latitude  longitude  \
# 0   https://www.google.com.br/maps/place/Parque+de... -15.733769 -47.843250
# 1   https://www.google.com.br/maps/search/Parque+d... -15.816968 -47.899443
# 2   https://www.google.com.br/maps/search/Parque+R... -15.642834 -47.831753
# 3   https://www.google.com.br/maps/search/Parque+V... -15.634504 -47.773727
# 4   https://www.google.com.br/maps/place/Parque+de... -15.798101 -47.851231
# ..                                                ...        ...        ...
# 67  https://www.google.com.br/maps/search/Parque+E... -15.803220 -47.839727
# 68  https://www.google.com.br/maps/search/Parque+D... -15.962544 -47.853273
# 69  https://www.google.com.br/maps/search/Parque+D... -15.866908 -48.055688
# 70  https://www.google.com.br/maps/search/Parque+E... -15.866802 -48.081953
# 71  https://www.google.com.br/maps/search/Parque+d... -15.816968 -47.899443
#
#    classificacao
# 0         Parque
# 1         Parque
# 2         Parque
# 3         Parque
# 4         Parque
# ..           ...
# 67        Parque
# 68        Parque
# 69        Parque
# 70        Parque
# 71        Parque
#
# [72 rows x 5 columns]

# %%
import folium

# %%
df_parques['classificacao'].unique()
# Out:
# array(['Parque', 'Permanentemente fechado', 'Belezas naturais',
#        'Parque ecológico', 'Reserva natural', 'Lago', 'Parque estadual'],
#       dtype=object)

# %%
len_p = len(df_parques['nome'])
len_p
# Out:
# 72

# %%
mapa_parkis = folium.Map(location=[-15.721,-48.077], zoom_start=10)

# %%
for parque in range(0, len_p):
    if df_parques['classificacao'][parque] == 'Parque':
        folium.Marker(location=[df_parques['latitude'][parque],df_parques['longitude'][parque]], icon=folium.Icon(color='green'), popup=str(df_parques['nome'][parque])+'<br>'+' - '+str(df_parques['classificacao'][parque])).add_to(mapa_parkis)
    elif df_parques['classificacao'][parque] == 'Parque ecológico':
        folium.Marker(location=[df_parques['latitude'][parque],df_parques['longitude'][parque]], icon=folium.Icon(color='darkgreen'), popup=str(df_parques['nome'][parque])+'<br>'+' - '+str(df_parques['classificacao'][parque])).add_to(mapa_parkis)
    elif df_parques['classificacao'][parque] == 'Reserva natural':
        folium.Marker(location=[df_parques['latitude'][parque],df_parques['longitude'][parque]], icon=folium.Icon(color='pink'), popup=str(df_parques['nome'][parque])+'<br>'+' - '+str(df_parques['classificacao'][parque])).add_to(mapa_parkis)
    elif df_parques['classificacao'][parque] == 'Belezas naturais':
        folium.Marker(location=[df_parques['latitude'][parque],df_parques['longitude'][parque]], icon=folium.Icon(color='cadetblue'), popup=str(df_parques['nome'][parque])+'<br>'+' - '+str(df_parques['classificacao'][parque])).add_to(mapa_parkis)
    elif df_parques['classificacao'][parque] == 'Lago':
        folium.Marker(location=[df_parques['latitude'][parque],df_parques['longitude'][parque]], icon=folium.Icon(color='lightblue'), popup=str(df_parques['nome'][parque])+'<br>'+' - '+str(df_parques['classificacao'][parque])).add_to(mapa_parkis)
    elif df_parques['classificacao'][parque] == 'Parque estadual':
        folium.Marker(location=[df_parques['latitude'][parque],df_parques['longitude'][parque]], icon=folium.Icon(color='lightgreen'), popup=str(df_parques['nome'][parque])+'<br>'+' - '+str(df_parques['classificacao'][parque])).add_to(mapa_parkis)
    elif df_parques['classificacao'][parque] == 'Permanentemente fechado':
        folium.Marker(location=[df_parques['latitude'][parque],df_parques['longitude'][parque]], icon=folium.Icon(color='red'), popup=str(df_parques['nome'][parque])+'<br>'+' - '+str(df_parques['classificacao'][parque])).add_to(mapa_parkis)
    else:
        folium.Marker(location=[df_parques['latitude'][parque],df_parques['longitude'][parque]], icon=folium.Icon(color='gray'), popup=str(df_parques['nome'][parque])+'<br>'+' - '+str(df_parques['classificacao'][parque])).add_to(mapa_parkis)

# %% [markdown]
# # Exportação do mapa para formato HTML

# %%
def export_map(map_file, map_image, map_obj):
    browser = webdriver.Chrome('chromedriver.exe')
    tmpURL = 'file://{path}/{mapfile}'.format(path=os.getcwd(), mapfile=map_file)
    map_obj.save(map_file)
    browser.get(tmpURL)
    time.sleep(5)
    browser.save_screenshot(map_image)
    browser.quit()

# %%
mapa = 'mapa.html'
imagem = 'imagem.png'

# %%
export_map(mapa,imagem,mapa_parkis)

# %%
#text_search = driver.find_element_by_tag_name('input')
#text_search.clear()
#text_search.click()
#text_search.send_keys(str(df['Nome'][1])+' Distrito Federal')
#text_search.send_keys(Keys.ENTER)
#url = driver.current_url
#print(url)
